# %%
from youtube_transcript_api import YouTubeTranscriptApi

ytt = YouTubeTranscriptApi()

video_id = '6GuyMZ-cSzE'

transscript = ytt.fetch(video_id,("en",))

# complete_transcript : str = ""
# for snippets in transscript:
#     complete_transcript = complete_transcript + " " +snippets.text

complete_transcript = " ".join(snippets.text for snippets in transscript)

# %%
complete_transcript
# Out:
# 'You will find tons of high-quality Python tutorials on YouTube. What I want to do different in this Python crash course is teach you Python by keeping in mind the use case of AI. So, if you are an AI aspirant who wants to build AI solutions or who wants to learn AI using Python, then this is the right video for you. Python is a general-purpose programming language. If I teach you all the features in Python, this tutorial video will easily be 10 hours. I don\'t want to do that. What I want to do instead is teach you only those parts of Python which are used to build AI. You might be wondering who am I to give you advice on this. I\'m Dhawal. I have 17 plus years of experience working for big tech companies like Bloomberg and Nvidia. Right now, I am the co-founder of AtliQ Technologies, which is an AI services company. We serve to our clients in US and UAE, and my team of AI engineers uses Python on a daily basis. Whatever I\'m going to teach you today is based on this real industry experience. On the screen, you are seeing the list of topics that we will be covering in this video. At the end, we will be building >> [music] >> an end-to-end project for customer feedback analysis, where we will have a front end in Streamlit back end uh using FastAPI. We will be using Gemini models for some of the text analysis, and as a database, we\'ll have SQLite. Let us begin by going over why Python is so popular in the world of AI today. The first reason is simple and readable code syntax. On the screen, you are seeing the code for reading a file line by line both in Java and Python. Tell me, which code is easy to understand? Well, Python. It is more like English. The second reason is rich AI ML ecosystem. If you go to PyPI, which is a portal which contains all the Python packages, you will find more than 800,000 open source packages. And you will find all the major AI ML packages such as PyTorch, TensorFlow, scikit-learn. Thousands of developers have put in a lot of time in building these open source packages and the ecosystem is so rich that anything that you want to do in AI, you will find a package in Python for that. And the third reason is strong community and learning resources. There are millions of developers who have spent time in making this ecosystem so rich that you want to explore any package, any concept, you will find a YouTube tutorial. You will find data sets on Kaggle. You have everything that you need to build a solid AI application available for free on internet. Before we install Python, let me address the burning question. Should you learn Python in the age of vibe coding where AI is writing all the code? Well, let me give you three reasons why you should have good fundamentals on Python. The first one is AI is writing the code, but you need to understand it. When you deploy the code in production, you are responsible for that code, not AI. So, if the code is wrong, inefficient, or insecure, it is your responsibility to fix it. Few weeks back, I was in California talking to my friend who is a manager in Apple. And what he was saying me is all of his developers are using AI to deploy the code, they ask them to review all the code. And if something goes wrong in production, that particular person, the developer, is responsible. They can\'t pass the blame to AI. Second, if you have strong fundamentals in Python, you can direct AI properly. You can help it in architectural decisions and you can fix some of the errors or hallucinations that AI is producing. Third, the skill has now shifted from writing all the code by hand to reviewing and orchestrating. Therefore, developers with strong fundamentals in Python who can work with AI can work more productively than those developers who do not know Python at all. With that in mind, let\'s install Python on your computer. The first step in learning Python is to install it on your local computer. Google download Python. Click on the first link that appears here. Click on this pa ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 20 
)

docs = splitter.create_documents([complete_transcript])

# %%
len(docs)
docs
# Out:
# [Document(metadata={}, page_content="You will find tons of high-quality Python tutorials on YouTube. What I want to do different in this Python crash course is teach you Python by keeping in mind the use case of AI. So, if you are an AI aspirant who wants to build AI solutions or who wants to learn AI using Python, then this is the right video for you. Python is a general-purpose programming language. If I teach you all the features in Python, this tutorial video will easily be 10 hours. I don't want to do that. What I want to do instead is teach you only those parts of Python which are used to build AI. You might be wondering who am I to give you advice on this. I'm Dhawal. I have 17 plus years of experience working for big tech companies like Bloomberg and Nvidia. Right now, I am the co-founder of AtliQ Technologies, which is an AI services company. We serve to our clients in US and UAE, and my team of AI engineers uses Python on a daily basis. Whatever I'm going to teach you today is based on this real industry"),
#  Document(metadata={}, page_content="this real industry experience. On the screen, you are seeing the list of topics that we will be covering in this video. At the end, we will be building >> [music] >> an end-to-end project for customer feedback analysis, where we will have a front end in Streamlit back end uh using FastAPI. We will be using Gemini models for some of the text analysis, and as a database, we'll have SQLite. Let us begin by going over why Python is so popular in the world of AI today. The first reason is simple and readable code syntax. On the screen, you are seeing the code for reading a file line by line both in Java and Python. Tell me, which code is easy to understand? Well, Python. It is more like English. The second reason is rich AI ML ecosystem. If you go to PyPI, which is a portal which contains all the Python packages, you will find more than 800,000 open source packages. And you will find all the major AI ML packages such as PyTorch, TensorFlow, scikit-learn. Thousands of developers have put in"),
#  Document(metadata={}, page_content='have put in a lot of time in building these open source packages and the ecosystem is so rich that anything that you want to do in AI, you will find a package in Python for that. And the third reason is strong community and learning resources. There are millions of developers who have spent time in making this ecosystem so rich that you want to explore any package, any concept, you will find a YouTube tutorial. You will find data sets on Kaggle. You have everything that you need to build a solid AI application available for free on internet. Before we install Python, let me address the burning question. Should you learn Python in the age of vibe coding where AI is writing all the code? Well, let me give you three reasons why you should have good fundamentals on Python. The first one is AI is writing the code, but you need to understand it. When you deploy the code in production, you are responsible for that code, not AI. So, if the code is wrong, inefficient, or insecure, it is your'),
#  Document(metadata={}, page_content="it is your responsibility to fix it. Few weeks back, I was in California talking to my friend who is a manager in Apple. And what he was saying me is all of his developers are using AI to deploy the code, they ask them to review all the code. And if something goes wrong in production, that particular person, the developer, is responsible. They can't pass the blame to AI. Second, if you have strong fundamentals in Python, you can direct AI properly. You can help it in architectural decisions and you can fix some of the errors or hallucinations that AI is producing. Third, the skill has now shifted from writing all the code by hand to reviewing and orchestrating. Therefore, developers with strong fundamentals in Python who can work with AI can work more productively than those developers who do not know Python at all. With that in mind, let's install Python on your computer. The first step in learning Python is to install it on your local computer. Google download Python. Click on the"),
#  Document(metadata={}, page_content="Click on the first link that appears here. Click on this particular standalone installer. You can also try this one. And if you have a different OS, you will choose the selected OS. If you want to use a specific version of Python, let's say 3.13, then you click here. Once you have downloaded it, you simply double-click it and just say install now. Make sure you are adding python.exe to your path. In the age of AI, you should not be stuck in installing something. If you face any error, just take help of AI tool. And now I'm assuming you have Python installed on your computer. I'm on Windows machine. I'm going to open my command prompt and I will just say Python {hyphen} {hyphen} version, which will show me the version of Python that is installed here, 3.14.4. So, this confirms that Python is installed okay. We will do our Python code practice via something called Jupyter Notebook. And that you can install by running pip install notebook. Pip is the utility that lets you install"),
#  Document(metadata={}, page_content='lets you install different modules of Python, which are available on pypi.org. PyPI is a central repository of all the Python libraries. You can see there are 821,000 projects. You name any functionality, for that there will be a Python package, okay? So, we just install the notebook. Now, I will create a folder to practice my Python. So, here in C code directory, I will create a new folder called Python practice for AI, okay? And then you can see code and then Python practice. So, see I\'m here and now I can say Python {hyphen} M notebook. So, that will launch a notebook, which is an interactive environment where you can run the code, okay? So, let me just quickly show you. So, here I\'m going to create a folder for my first tutorial, which is data types, functions. And when you refresh, you will see that folder here. And here you can click on a new Python notebook. So, now here I can write Python code, see? When I say "Hello world", it prints it. So, this is the Python code that I'),
#  Document(metadata={}, page_content="Python code that I run, all right? So, our setup is complete. The first topic we'll look into is data types in Python. So, let's give a name to our notebook. So, I will say data types and for loop. We'll cover for loop as well. Assume you are a CEO of a company. You are a Mukesh Ambani or you are Sundar Pichai. You want to know the finances of your company. So, basic finances are revenue and expenses. Revenue minus expenses is profit and there is profit margin. Let's say you want to calculate that in Python. How do you do it? Well, so I will create a variable called revenue, okay? So, let's say the revenue of my company is $50 billion. So, when you do this in Python, you are creating a variable called revenue. Variable is a container that holds some value. Now, here you can press key B, okay, B B for Bob to create a new cell. And this is individual code cell that you can run. So, if I do type of revenue and here you can hit control enter. It will say int. Now, every variable in Python"),
#  Document(metadata={}, page_content="variable in Python is an object. And the object can contain any value. It can contain integer, it can contain string, whatever. So, Python is a dynamically typed language. It's not statically typed like Java or C++ where, let's say you have integer variable and you cannot assign any other value. Here to uh revenue, I can assign a string also. See? Now, the type of my revenue becomes string. It has developed this spiritual attitude of uh non-attachment, okay? So, that's why Python is actually very popular cuz it's quite flexible. So, without going into our samosa business, let's focus on our revenue. I can have another variable called expenses. So, let's say my company is amazing like Nvidia. My expenses are very less. Okay? And my revenue is $50 billion. Expenses is 10. To calculate profit, it is simple, right? Revenue minus expenses. And when you say profit, see? $40 billion is my profit. And if you want to calculate the profit margin, it's a simple math. Margin will be profit"),
#  Document(metadata={}, page_content="will be profit divided by revenue. Okay? so if you do margin, see? And pause the video and tell me what will be the type of margin. Well, float. If you have done programming before, float is a data type that holds number with fractions, okay? Whereas these are whole numbers, that's why they are called integer. If the number has fraction, okay, 80.2, 80.3, whatever. Here is 80.0, then the data type is float. As I said, every variable that you create is an object and you can see the object ID by typing ID function. Now, I attended Google I/O recently and uh they covered for my expenses. So, let's say I had an expense on Mexican food, okay? So, I will say Mexican food at Dishdash in Sunnyvale. The food here was awesome, by the way. You can create a string variable like this and the type of that will be string. This is pretty straightforward. But what is interesting here is you can create string in a different way. So, here we use double quote. You can also use single quote, okay? So,"),
#  Document(metadata={}, page_content='quote, okay? So, let\'s say I See? That also works. And this is useful, the combination of single quote, double quote, is useful when you had quote within the string. So, let\'s say if I had something like, let me remove this. Uh I would love to have a Mexican food. So, see here there is a single quote and double quote, okay? So, for this kind of scenarios, it is useful. If you have more than one line of string, you can declare that string by using triple quote. So, see? Triple quote. Now here, I can type multiple lines, okay? Expense for Y more rental, and so on. See? And the type of the this variable will be string, and you can also say len. So, len is a function which will let you uh count the characters. So, if you count characters, you know, totally it will be 69 character. It\'s It\'s the length of your string. Now, if you\'re a Java programmer, you\'ll be like, "Why don\'t you use camel case convention like this?" You know, where you have a word, and the another word is a capital.'),
#  Document(metadata={}, page_content="word is a capital. Here, we are separating two words by underscore. And the reason is in Python, there is this style guide called PEP 8, okay? So, according to PEP 8, the variables should be defined using snake case convention. Snake case is basically you have your words in small case, and they're separated by underscore. In Jupyter Notebook, you can run a cell by hitting control enter, or you can simply click on this. See? This will also execute the cell. To create a new cell, you can uh click on this plus. If you want to execute all the cells, you can say run run all the cells, and it will run it. And this number 18 19 etc. shows the order of execution in Jupyter Notebook. By this time, you have realized Jupyter Notebook is nothing but an interactive way to run your Python code. You can also create a markdown cell. So, let's let me create a cell above it. And how do I do it? By pressing a key A. A for apple, okay? And in this, I will change the type of the cell to markdown. And"),
#  Document(metadata={}, page_content="to markdown. And here, I can use markdown language. I can say data types tutorial in Python, see? This way you can document these things. So, here I want to add one more markdown saying that for naming convention is usually snake case, right? Usually snake case. And refer to this particular guide. So, notebook, just like your regular notebook, allows you to make some notes and also allows you to execute the code. Now, let's say you, Mr. Sundar Pichai, has analyzed the revenue and expenses of Google for last quarter, but you want to do analysis on more quarters. You have not just one revenue, you have three revenues and three expenses for quarter one, quarter two, quarter three. How do you store that in Python? Well, you can create three variables, but there is a better way called list. And the way list works is you will have a name of the variable, then this bracket, and these are the three revenues that you have, okay? So, if you do the type, it will say this is a list. And if you"),
#  Document(metadata={}, page_content="a list. And if you want to get the first revenue, you will say zero. So, this is the index operator. If you want to get the last, you know, the first element from last, you can do minus one. So, minus one is 55, then minus two. Basically, you are going from reverse, okay? From back forward to front. And you can also go from forward to backward, you know, by using this positive index. You can also get a sublist, okay? Let's say I want to get uh Q2 and Q3 revenue. So, that you can do by doing this, one colon three. So, the indexes in the list, they start with zero. So, this one is zero, this one is one, this one is two. Now, I want to get Q2 and Q3 revenue. So, the index I'll refer to is one, okay? So, one will include that list in the output and go all the way three till three, but do not include three, which means it will go from one to two. So, the way this list is stored is, you know, you have this kind of uh locations, okay? So, this is zeroth location, this is one location, this"),
#  Document(metadata={}, page_content="one location, this is second location, and there is a variable called revenues, okay? So, revenues is a variable, it's an object. It is pointing to this area in memory, which is contiguous memory locations, okay? And when you say revenues zero, it will give you this, one will give you this, revenues two will give you this. Len of revenues will give you the length of that particular list. If you refer to an index, let's say 10, we don't have 10 elements, then it will throw an error. All right, now let me create the list for both revenue and expenses. So, these are the revenues and expenses I have. Now, when I want to print the revenues one by one, you can use something called a for loop. You can say for revenue in revenues, print revenue. So, for loop will take these elements one by one, and it will do the operation. In Python, the block is specified by indentation. If it was JavaScript or Java, you know, you will use this kind of brackets. Python doesn't have those brackets, it's all"),
#  Document(metadata={}, page_content="brackets, it's all indentation, okay? This this space. So, here I can type anything. So, I can say uh print revenues. And by the way, to print revenue to refer to the revenue variable you can say this, see? Or you can use something called Python format string. So, format string starts with F, and you can specify a variable inside the string, see? Inside the double quote. So, now I can say this. Now let's calculate profit margin for each of these quarters, okay? So, this is again quarter one, quarter two, quarter three. Revenues and expenses for quarter one, quarter two, and quarter three. I want to calculate margins for each of these three quarters. How do I do that? Well first of all, you need an index so that you can refer to the expenses list as well. And the way you do index is you can say for I in length of revenues. Okay? So, what will happen is this I will be Actually, you will do I in range actually. Okay? Range Range means it will give you range from zero till length is"),
#  Document(metadata={}, page_content='zero till length is three. So, zero till two actually, okay? So, so zero, one, and two, okay? So, this way you are getting these index variable. And now I can print revenue, see? When I say revenues, it will print the revenues. Similarly I can print expenses, right? Expenses. And now I can calculate the margin. So, I can say margin is equal to revenues or rather let me calculate profit first. So, revenues minus expenses is the profit. And then, margin is nothing but profit and then revenues. Control enter, and see, this is the margin for 80% margin for quarter one, 50% for quarter two, 36.36 for quarter three. I want to print this in a good format, you know, so I can use Python format string. I can say margin for I will just say I, okay? This is how you refer to a variable inside format string. Whenever you put F in front of double quote, it becomes a format string. Inside the format string, you can refer to a variable, so see, I is a variable, and the values will be 0 1 2. And to'),
#  Document(metadata={}, page_content='be 0 1 2. And to print the value of that variable, you can put this um curly bracket, okay, around it. Now here, I can say margin. See, margin 0 1 and 2. Now, there are so many decimal places, so you can do formatting by adding colon .2f, which means it will print only two decimal places. Now, you want to say, "Okay, this is for quarter one." See, instead of 0 1 2, you want to say Q1, Q2, Q3. So, see, index is always starts with zero. So, if you want to refer to Q1, it is actually zero index, so you have to add this plus one here, and you can say Q, okay? And now see, margin for Q1 is this, Q2 is this, and Q3 is this. Instead of printing it, if you want to store margins in another list, another Python list, you can do that as well. The way you initialize Python list is by saying this, okay? So, let\'s say margins is my Python list, and I want to run this particular the loop, okay? I want to run it. And once margin is calculated, I want to append this to this list. You will use this'),
#  Document(metadata={}, page_content="You will use this append method margins.append. And whatever margin you are calculated in that for loop iteration, you will uh append it. And here you can just say margins, and it will print it. See, now margins are stored in a Python list. One problem that I see with the variables I have created here is these two different lists, okay? And I have to kind of assume that this is Q1, Q2, Q3. What if this list has more values? And it's kind of all manual management. Wouldn't it be good if we had a structure, one object where you can store Q1 revenue and expense? Another object where you can store Q2 revenue and expense. Q3 revenue and expense goes into third object, and so on. That would be nice, right? So, that is something that you can do using something called dictionary. Dictionary is like a hash map, if you have done Java programming. Hash map, okay? A And And the way you define a dictionary is I will create a variable called revenue. And you will just give a key and value. So,"),
#  Document(metadata={}, page_content="key and value. So, let's say for first quarter, okay? My revenue is 50. And my expenses is equal to 10. So, this is how you create this dictionary, okay? And when you say type, it says dict, okay? Here, by the way, you can do this as well, okay? Both are equally valid. Now, when I want to calculate the margin, or let's say profit for this first quarter, I can say fin revenue. This is how you can refer to this revenue, which is 50, minus fin expenses, and you get See, this is clear because you are having one object. Okay, this is like Q1 object, which contains revenue and expenses both. If you want to add a new value right here, you can add that. You can just simply say fin of profit. When I do that, it will create a new key in the fin object, okay? And see, now my fin object, which is quarter one, looks something like this: revenue, expenses, and profit. You can create a list of such dictionaries, okay? So, I can say financials. I have a list, and each element is a dictionary type,"),
#  Document(metadata={}, page_content="a dictionary type, okay? So, this is Q1. And by the way, you can do comments by using this hash sign, okay? So, hash sign lets you add comments. So, comments are basically code that doesn't get executed. It is for documentation. Now, see, I have a list of financials. Now, to calculate profit, and let's say add margins in each of this, I can say for fin in financials, so fin object in each iteration will contain Q1, Q2, Q3. So, I will say profit is fin revenue minus expenses, and fin margin is this. Once this loop is executed, when I print financials, see, financial has revenue, expenses, and margin. Isn't it wonderful? Now, I'm a very good disciplined Python programmer. I want to know what this object is for. Is it for Q1, Q2, Q3? You can do that by creating something called a nested dictionary. So in a nested dictionary, you will have key as Q1 and the value is another dictionary, see? So this is an outer dictionary and the value of each of the element is another dictionary. So Q1,"),
#  Document(metadata={}, page_content="dictionary. So Q1, Q2, Q3. And then to iterate over key and value, okay? So to iterate over key and value, you will say for quarter and then data in financials.items. When you do items, basically it will print quarter, see? Let me just print it quickly. So you see, in each iteration, it is printing Q1. So here is key value, okay? For key value in financials.items. Items is a very convenient method to access the keys and values. So here now you can write your logic. You can say margin is this and now see, you exactly know what is the margin percentage for each of these quarters. Now someone introduced a bug in my upstream system and now they are throwing this kind of objects at me where the revenue is negative. See, revenue can't be negative. So you can add a check to ignore the revenue, okay? So see, when we write code, we meaning when humans write code, when AI writes code, there will always be bugs, okay? Bugs is the constant of life. So in the code, you need to handle those bugs."),
#  Document(metadata={}, page_content="handle those bugs. So I want to ignore that object where revenue is negative. How do I do that? Well, there is something called if condition. If you are a programmer, once again, if sounds like your childhood friend, you will be very much aware about it. So here, I will say if data revenue is less than zero, then you will skip that particular value. So I'm going to skip the value here. And then I will do continue. Continue means it will go to next iteration. It will not execute the code that I'm going to write here. See, this code it will not execute when I say continue. But that will happen only if the revenue is less than zero. If revenue is not less than zero, then we want to do our usual logic of calculating margin. This is how the code looks. Let's run it. See, invalid revenue for Q4 missing. I mean, if I had this invalid revenue here, then it will skip that particular part. To summarize, dictionary is essentially a hash map where you can access the value by using a key. Now,"),
#  Document(metadata={}, page_content="using a key. Now, let's talk about tuples. So, I'm going to change it to this markdown and I will say this discussion is on tuples. So, let's say you have RGB values, okay? Now, we all know every color is some combination of RGB. For example, purple. Purple is red 128, green zero, and blue 128. You can define purple color using tuple. So, tuple is sort of like a list, see? But in list, you use square bracket. Here, instead of square bracket, you use this other bracket. And then you can do same thing that you were doing with the list, where you can access all these elements. But one difference between tuples and list is that tuples are immutable, which means you can't change its value. So, if I try to change, see, in a list, I can change the value, but here if I try to change the value, it will say that this object does not support item assignment, which means once you have defined tuple, you cannot change it. And it's good. See, purple color by definition means this. I don't want"),
#  Document(metadata={}, page_content="this. I don't want anybody to change it, okay? So, therefore, for this scenario, tuple is uh ideal to use. And if you want to get individual components of RGB, you can do something like this. R {comma} G {comma} B is equal to purple. And when you print R, see, 128. When you print G, it is zero. When you print blue, it is 128. Now, let's say you are an artist. You want to mix two colors, purple and yellow. And the color yellow looks something like this. So, how do you mix these two colors? Well, I will create a new variable called mixed, and then I will add purple into yellow. And then divide that, okay, divide that by two. So, let's divide that by two. And here, it will be element number one, element number two. Okay. And when I say mixed, see, this is the color. Now, the color has integer value. See here, we are seeing fractional value, float value, dot point five, point five, etc. If you want to get the integer value uh and the floor of the division, you can use double slash, okay?"),
#  Document(metadata={}, page_content="double slash, okay? Double slash will give you the floor. Floor is like in 191.5, the floor is 191, okay? So, see, now you get the mixed value. This is how you can mix colors in Python. You can download this code by clicking on a link down in the video description. And when you open a notebook, there is a super important section towards the end. It is called exercise. See, if you watch these videos as if you are watching a Netflix movie, that's not going to work for you. You have to practice along with me. And to practice, you need to work on the exercises, a new problem statement. So, I have defined a problem statement here. Please practice it on your own. If you're stuck, take help of any AI tool. Learning coding is like learning cricket. If you want to play cricket, will it work if you continue watching IPL and continue watching Suryavanshi or Kohli playing shots? No. You have to take a bat and go on the field and start playing the cricket, okay? So, please start playing this"),
#  Document(metadata={}, page_content="start playing this coding cricket game by working on this exercise. I will now explain functions in Python for which I'm going to create a new folder. Uh refresh. I see functions. Create a new Python 3 notebook. Previously, we calculated revenue and margin using simple Python cells. But what if you are getting a file, let's say you are an executive in the company and your finance team is giving you a file with uh tons and tons of revenue and expense numbers. Every time doing that revenue minus expenses a bit combustion. We need something that can modularize our code. And that way is function. The way you define function in Python is by saying d e f, then the name of the function, let's say calculate margin, and then the input parameters. Revenue and expenses are my input parameters. And below that, you can write a code for calculating margin. And then, you can say return margin. Now, watch what happens when you say calculate margin, and when you say 50 is my revenue, expenses 10. See,"),
#  Document(metadata={}, page_content="expenses 10. See, it is calculating that. So, now it has become sort of like calculator, okay? It has become it's a function in calculator where you can supply any revenue, any margin, and it will calculate it. So, this is the way people write modular code, okay? You can also create this kind of variable revenue and expenses and pass it to a function. In this function, I am returning one value. You can uh return multiple values as well. Let's say I want to return both profit and margin. The way I do that is I will uh give a function calculate profit and margin and then calculate both of the parameters and uh return them using comma. Now, when you do that, it will return it as a tuple, okay? So, let me call this function. See, revenue and expenses, profit {comma} margin, okay? So, when I enter it, so here, my profit is this, my margin is this. And if you have captured this thing in a single variable, then that type of that single variable will be a tuple. See, whenever you are saying"),
#  Document(metadata={}, page_content='you are saying this, uh one variable {comma} another variable, essentially it is a tuple. If you say something like this, that will [clears throat] be a list, okay? So, here, this is a common practice when people want to return multiple values in any Python function, they uh return it as tuple. And then later on, if you want to access the first and second value, so first value is your profit, okay? Second value is your margin. Assume you are a programmer in Google and you are looking at a big code base. When I was at Bloomberg, we used to work on a code base which will have millions of lines of code. Navigating through code, understanding that code becomes very difficult. Now, if I have a function like this, how do I know what is the data type of a variable, you know? Like my input parameter. How do I know what is the data type of my return value? The function here is very simple, but in real life you will have huge functions, okay? So, in Python, uh there is no data type intrinsic'),
#  Document(metadata={}, page_content="data type intrinsic data type because it is a dynamic language, dynamically typed language. But, there is something called type hint. So, you can give a hint to a programmer who is reading the code or nowadays AI is reading your code, AI is writing it. So, to any AI, you can give it a hint by saying colon after the variable, colon, and the data type. So, you're saying revenue is a float, expenses is a float, okay? And the value that it will return is also a float. The way you specify that is after your bracket is over, you will put this particular arrow, and you will say float, okay? So, here, uh once again, you are not defining a type. If you assign revenue a string value, it's going to work. But, what you're doing is giving a hint, okay? So, this thing is called type hint. It is just a hint to a programmer who is reading the code or an AI who is reading the code. Let's look at one other useful functionality. I have this function which is calculated my expenses. So, when I went to"),
#  Document(metadata={}, page_content="So, when I went to Google IO, let's say this was my food expense and this was my Waymo car expense. By the way, Waymo car was awesome, okay? I felt as if the ghost is riding my car. This is fine, but let's say I want to add a new expense, okay? I want to add an expense for my hotel, okay? This was my expense for the hotel. Now, this is not going to work because this function takes three arguments. So, how do I make a function which can take dynamic arguments? One time I can supply two, one time I can supply three, and so on. The way you do that is by using this thing called args. Okay, so I will define a new function called calculate total expense, and I will say star args. So, let me just print args to see what it will do. So, here I will just say calculate expense. And see, it is printing it. So, it takes that as a tuple. So, this type is tuple, and you can supply any number of arguments here. Now, to calculate total, you can use this method called sum. Okay, or you can you can run"),
#  Document(metadata={}, page_content="you can you can run a for loop on it. And see, now let me just My total expense is 18. I can keep on adding this. So, args allow you to pass dynamic number of arguments in your Python function. Now, I don't like this function because I don't know what this expense for is. Is it for food, bill, etc.? What I like is functions like this where I can say this is the expense for rent, this is the expense for phone bill. So, you have a named argument here. Okay, and this looks good. But, what if I want to add a new expense here? Well, there's another thing called kwargs. So, here you will put two stars. See, in args you will put one star, here you put two stars, and this kwargs will be a dictionary. So, let's print this first so that you understand what this is. See, it took that as a dictionary. And in a dictionary, if you want to calculate the total, you will iterate through the key and value. The way you do that is for key value in dictionary.items, then you add the total. You you ignore"),
#  Document(metadata={}, page_content="You you ignore key actually. You just add the total. And uh you add every value to the total and you compute it. So, now what happens is my total expense is this. My expense for Waymo car was $20. So, now this you can keep on adding it. All right. And now comes the most important section, folks, which is an exercise. I want you to build the chai bill calculator, okay? You all go to the chai stall, build a calculator, and give it to your favorite chai wala. Now, let's talk about a very important topic of classes and objects in Python. Classes and objects are used to do something called object-oriented programming or OOP in software. If you are appearing for an interview, they will ask you questions on this. So, let's understand why classes are needed. So, here I have information on two employees, Mohan and Fatima, and their salaries. And when you want to calculate their bonus, you can write this kind of function. And this works okay. But what if you have 500 employees? Are you going to"),
#  Document(metadata={}, page_content="Are you going to create 500 variables like name one, name two, name three, name 500, and so on? Second, you can have more attributes like the department, the age, the email of an employee. Are you going to say email one, department one, and so on? That is too cumbersome. You can also have more methods, promote, send email, and so on. So, all of this information seems like they are scattered. What if we can bundle all of this together into a single entity? We can bundle data and behavior into a single entity and that entity is called class. The way you define class in Python is you will say class and the name of the class, which is employee here, and then you will have a constructor, which is def {underscore} {underscore} init. If you have used Java or C++, you might be aware about this constructor concept, which is this is how you initialize the class. And in Java, there is this thing called this, so that same thing in Python is called self. So, here I'm creating a property in a"),
#  Document(metadata={}, page_content="a property in a class, okay? So, classes will have two things, uh properties and the methods. So, this is the first property and the second one is salary, okay? So, this is how you have initialized it. And the method that you have here is calculate bonus. So, calculate bonus. And here, uh you will specify self. So, whenever you are defining a method inside a class, it will always take this self as a parameter if the method is going to be associated with the instance. I I will explain what I mean by this. And here, you will say return self.salary. Let's say you're getting 10% bonus, okay? So, that's it. Now, when you are creating an instance of a class, so here, let's say I will say employee, the first employee is Mohan. Okay? And Mohan's salary is 80,000, okay? $80,000. See? This is how you create the first employee. It's it's so easy. And I can say Okay, let me create this and I can say employee.name. See, it is Mohan. employee.salary is 80,000. So, this is going to call this"),
#  Document(metadata={}, page_content="going to call this constructor which is init method. Mohan will go in a name, this will go here and it will assign those values to name and salary which are the properties or attributes of this class. Now, I can call a method called calculate bonus. And see, this is the bonus for Mohan. Okay. You can create another instance. Now, now you want to want to create 500 employee instance, it's so easy. Okay, employee one, employee two. And this is very intuitive even to a human eye and human brain, right? You have an entity which has all these methods, all these properties actually, name and salary are properties, and you have method. You can have additional method. You can have another method called send email. Employee can send email and you can define the behavior here. Okay, you can have any number of methods. So, this a class here, this particular thing that you see is called a blueprint. And here, what you have done is created an instance. So, EMP1 is one instance of class. EMP2 is"),
#  Document(metadata={}, page_content="of class. EMP2 is another instance of class. It is sort of like I can have a class called human. Okay, and the human class can have, let's say, name, age, all of that. Instead of age, maybe I can take the birth year. I can have it something like this. And when I say get age, you can compute the age. Okay, I'm using the daytime module in Python. All right? Now, here I can have myself, right? So, let's say double is one instance of human. See, I'm part of humanity. I have two eyes, two legs, I have a certain structure of my brain, and you, the person who is watching the video is also human, okay? So, individual humans are the instance of the class humanity. So, here, let's say this is my name, and I can say get age, and it will get the age for a person, right? Here, you can have a different person, for example, Virat Kohli, okay? What is his birth year, by the way? Okay. I don't know, I'm just going to assume something, and Virat dot cat age, see? It's a very simple concept,"),
#  Document(metadata={}, page_content="simple concept, essentially. You have this class as a blueprint, and then these objects which you are creating are the individual instance of the class, and they can interact, and when you're writing a big code base, creating classes make things easier for you. There is another way to define a class, and that is using a Pydantic module, okay? Now, you need to install Pydantic module, so you can just go here, and you can say here, pip install Pydantic. So, that will install the module for you. And let's say you are defining a class for a recipe. So, a recipe can have title and calories. So, in Pydantic, the way it works is you have a class which you derive from a base model, and you will say type hint, okay? Title colon str, title calories colon integer. Now, Pydantic classes do not have methods. They are just list of fields. You will be like, you can do this using Python dictionary well. Well, you can do it, but by identity classes will enforce the types. Okay, so title can only be"),
#  Document(metadata={}, page_content="title can only be string. Calories can only be integer. It is the intrinsic behavior of a by dating class. Okay, so let's say I want to make a dal. By the way, I'm going to cook dal today. My wife is working today, so I make really nice dal fry. So I'm going to cook that. So now you can create an instance of this by identity class by saying that title is equal to yellow dal, calories is equal to 280. See, notice the difference between the syntax between your regular class and by identity class. Okay. Now, I can say dal.title and it will do that. Now see, title here is a string. Instead of string, if I assign number, what's going to happen is is going to fail. See, validation string. So this way, if you want to create a blueprint of an object where you want to have some kind of type enforcement, then by identity will help you with that. When we will look at some of the LLM calls, you will find that having by identity class will be very useful. And now is the most interesting part,"),
#  Document(metadata={}, page_content="interesting part, folks. Exercise. You're going to create a YouTube channel class for my own channel and just share the code with me. Maybe I can use it in my real work. Now comes a very interesting part of this tutorial, which is calling LLM. When you're using chat GPT, you are calling LLM via chat GPT app. But here I will show you how you can call it programmatically. For this, we are going to use Google Gemini model. Okay. So here we will look into the documentation. And the code is pretty simple. Okay, so I will just copy paste this code here. And you are importing Gen AI module from Google. And then you are creating a client. See, this is the class. Okay, and this is the object. And you will say client.models.generate_content. And Gemini has different models. Okay, 3.5, 3.5 Pro Flash, and so on. And then you will ask your actual question here. See, if you see all models here, you will see all kind of models. We are using 3.5 Flash. And if you look at the quick start, you need to"),
#  Document(metadata={}, page_content="start, you need to install Google Gen AI module for this. So, let me go to my command prompt here, and you will just say pip install Google Gen AI. You have to install the module, okay? Otherwise, you will get an error. The second thing you need to do is you need to set up your API key. So, here you can just say Gemini API key. And just go to this ai.studio.google.com using your uh Google uh account login, and then you can create an API key. So, just click on API key. It will create the key, this like long-looking string for you. And here you can uh create a project if you don't have a project, okay? So, just just create a project here, and just say this is the API key for my Python tutorial. Create a key, and this is the API key, this long-looking string. You click on this to copy the key. And what we will do is here, you know, in in this folder you will create a file called .env. Okay? And in this .env file, let me open with Notepad ++, you will uh say Google API key equal to"),
#  Document(metadata={}, page_content="API key equal to copy-paste that key, okay? So, just to summarize you are in this folder and here you have created this .env. I don't know why this is not visible here, but here you have .env with Google API key mentioned, okay? And this is uh like your password. So, make sure you're not sharing this API key with anyone else. Google offers uh generous free credits. So, for this tutorial the credit should be okay. If it goes above the limit, maybe you can spend some money uh and buy some credits. That way you can run your code. Now, the way you load that API key is by using a module called .env. So, we are going to install .env module. Anytime throughout this tutorial, if I don't show you, just use your common sense and install the module. Use AI tools to find help, okay? Now, when you call this method from .env module what's going to happen is it is going to load that key into an environment variable. And this Gemini API internally uses that particular environment variable. So, now"),
#  Document(metadata={}, page_content='variable. So, now when I run it, what\'s going to happen is it\'s going to make a call to Gemini 3.5 flash. It is going to ask it a very important question that I have pasted here. And see, wonderful. You just wrote the code to call LLM programmatically. Now, what if I\'m building an app which asks for ingredients, the cuisine, you know, Italian, Mexican, etc., the diet, and it will generate a recipe for me. Wouldn\'t that be something amazing? So, let\'s do that. So, here I\'m going to define a function called generate recipe where it will take a list of ingredients. You know, tomatoes, potatoes, wheat flour, whatever. And then cuisine can be Italian, Mexican, Indian, and diet can be vegetarian, vegan, uh etc. In this function, I\'m going to write a docstring. So, docstring is a documentation for this function. So, at the beginning of the function, you are saying, "Okay, what is the purpose of this function? What can cuisine be? What can diet be?" And so on. And then in LLM, you will pass'),
#  Document(metadata={}, page_content='LLM, you will pass in a prompt. So, the prompt is a format string. You\'re saying, "Generate food recipe using these ingredients." Okay? So, ingredients is a list, and when you want to create a string out of a list, you use this kind of operation. So, let me just quickly show you so that you understand. When I have ingredient list like this, when I do this, you are simply getting a string, comma separated string with the ingredients, okay? So, here I\'m saying, "Generate a food recipe using these ingredients. Cuisine is whatever is the cuisine, diet is that diet." And the remaining code is same as what we wrote before. You are going to call Gemini model. Okay? So, let\'s do control enter so that it\'s executed. And then we will generate a recipe. Folks, I\'m going to cook this today, okay? I have tomatoes, lentils, onion, jeera. I\'m going to cook the dal, okay? Jeera tomato dal. Yes, see? If you want to do pretty printing, you can just say print here. Isn\'t this amazing, folks? Here, I can'),
#  Document(metadata={}, page_content="folks? Here, I can have a different uh recipe. So, let me just copy paste this thing here. And instead of Indian, let's say I want Mexican food which is vegan. I have ingredients as corn, black beans, uh avocado, and it's generated recipe for vegan Mexican corn and bean salad. This is so amazing. Now, let's do one thing. Let's create a a app if functional app using this particular code. So, what I will do now is open my Visual Studio Code. If you don't have Visual Studio Code, install it. It is a very popular free IDE that lets you write code. So far, we are using Jupyter Notebook, but that is good for learning purpose. If you're building any production grade application with multiple files, etc., then you will use VS Code or PyCharm or any other editor. So, let's open a folder here called Python Practice AI. Okay. And here, I have this called LLM notebook. Now, I have the Cloud Code extension, so I have the subscription of Cloud Code. And I'm going to ask that check this and create a"),
#  Document(metadata={}, page_content="this and create a Streamlit app that can generate recipes for me. Now, why am I showing wipe coding? Well, because wipe coding has become a new normal nowadays. If you get hired as a Python programmer, you will be using wipe coding. So, I want to show you what's happening in the industry today. Streamlit, by the way, is a way to create a UI application, okay? So, see, here what it did is it created this thing called a app. It used the notebook that we created by the way, okay? So, it used this particular notebook that we had and it created this recipe app. And the recipe app looks something like this where you have Streamlit as STC. You have all this beautiful code. And let me just run this code first so that you understand what's going on. To run it from VS Code, I will start the view and terminal. You start it and then go to that particular directory and here you can say Python M Streamlit [snorts] run recipe app.py. Now, what it will do is it will open a browser window. And look at"),
#  Document(metadata={}, page_content="window. And look at this, folks. Your your application is ready, see? In just one prompt, we created a UI app. So, here you will specify all the ingredients. Tell me what kind of food you want to eat. I will say aloo peas with flour. I hope you're getting where I'm going with this. The cuisine is Indian. The diet is vegetarian. And generate a recipe. And it give the error because 2. 0 flash is not available. So, we need to uh use whatever model we have in this, see? I I want to use this flash model somehow. See, Y coding is not perfect. See, this shows that Y coding is not perfect. You need to have understanding of your code is doing. Otherwise, if you treat it like a box, then you know, you'll have problem because this AI can always make mistakes. See, it generated a recipe, aloo matar paratha. I hope it created a recipe for samosa. But this is so powerful. You have a front end working where you can give the input and you can generate a recipe, okay? So, Streamlit, folks, is a way to"),
# ...
#  Document(metadata={}, page_content="used to happen is somebody else will deploy program B. Okay. And see this this module, for example, request is not part of the program. It is outside in the global directory somewhere. Now program B requires, let's say request 2.0. So they need a different version of this request module. What will happen is somebody will go and they will upgrade this version to 2.0. But when they do that, this program might break because between 1.0 and 2.0 there might be a backward incompatible change. When this program was tested in dev environment or alpha, it was tested using request 1.0 module. Now all of a sudden somebody is updating the dependency and things may break. Okay, they it's not necessary they will break all the time, but there'll be occasions where things will break. This program will crash or show an error and so on. So this used to happen at Bloomberg when I was working when we were having a common servers uh between multiple teams or even within one team. You know, there can be"),
#  Document(metadata={}, page_content="know, there can be multiple programs. So to solve this problem, what you do is you use something called uh virtual environment and generic generic term is containerization. You know, there's Docker and things like that. So, Docker and virtual environment is kind of similar concept. They're actually different concept, but conceptually you want to include everything that you need, all the dependencies in your one package. So, what we started doing at Bloomberg is we came up with this virtual environment or containerized environment where, let's say you have global Python installation, okay? You have a couple of modules. So, we don't care what those modules are. When we ship this program A, okay? So, let's say this is program A. Program A is code, right? Your business logic. But, other than that, we will have complete Python environment. So, there will be Python, there will be other libraries like request, pandas, everything is packaged into this artifact. So, when you deploy A, it goes"),
#  Document(metadata={}, page_content="deploy A, it goes as a complete package. Whatever program needs, everything is present in that container. So, you don't have to look outside. Outside, if somebody upgrades something, you're not affected. And whatever you have in your package, program B cannot use it. So, program B will have similarly their own code for the business logic, right? This is their own code. And they will have their own Python, pandas, etc. Now, one obvious question you will have in mind is this is redundant space that you're occupying. Well, that is true, but space is very cheap nowadays, okay? So, what is important is program should work. Program should not break. Functionality of your software should stay intact. And this kind of packaging approach gives you that expected outcome. So, for our project for analyzing feedback from customers, what we are going to do is a virtual environment where we will have all the Python libraries or everything that we need in a one container. And for this, you need to"),
#  Document(metadata={}, page_content="this, you need to install UV Python package manager. So, go here based on your operating system, install it. I have Windows, so I open my PowerShell. See, copy here. Okay? Go to a PowerShell. Windows PowerShell. Copy-paste this. Run it, and it will install your UV. Once UV is installed, you need to init this directory. And the way you do that is uh you will go to view, open the terminal. And here, just say UV init. So, it will initialize your uh UV Python environment. And you will get files such as pyproject.toml. Now, in this file, you will mention all your dependencies. What are the packages that I need? Well, I need all these packages. So, you will do that. Okay? It also created python.version, which is 3.12, and so on. Now, that you have necessary dependencies in pyproject.toml, you will run a command called UV sync. So, what's going to happen is it has installed all these libraries locally in this directory called .venv. Okay? So, here, if you look at libraries, see, you see all"),
#  Document(metadata={}, page_content="see, you see all the Let's say you need FastAPI. Okay? See, FastAPI, you have FastAPI here. And not only that, all the dependencies of FastAPI. So, let's say FastAPI needs 10 other libraries, they are also installed. So, this way in this .venv environment, I have everything. All the libraries, everything that I need for this particular project. This kind of approach gives you reproducibility. You know, like predictable output. And to initiate the virtual environment, because see, if I I run Python right now, right? See, it will use the global Python version, which is 3.1 4. whatever, right? But what I want is I want to use whatever is in my virtual environment. So, for doing that, let me go I I don't like PowerShell, by the way. So, I'm going to go to normal command prompt here. And here, I will initiate my virtual environment. And the way you do that is you will say venv scripts activate. And you see this? Now, my Python environment is activated. So, now, whatever command I run, see,"),
#  Document(metadata={}, page_content="command I run, see, right now now it is saying 3.12.13, because it is referring to the local Python here. It is referring to local libraries here only. When you are inside the virtual environment. Now, I will first work on the back end. Back end will take the review as an input, and it will use Gemini's API to mark it as positive, negative, score it, etc. We have done this kind of coding before. So, we are not writing everything from scratch. All right, so let's create this file. Um I'm going to create this file here, api.py. Where I will import certain necessary modules. So, you all know we're are to use GenAI from Google's Gemini model and FastAPI. This is something we have done before. Now, to define an endpoint, you will do something like this, okay? So, here you are creating an endpoint called less analyze, where you will pass a review. Now, what exactly is this review? We need to define a Pydantic class for it. And my Pydantic class is pretty simple. In the review, you are"),
#  Document(metadata={}, page_content="the review, you are passing a text. So, whoever is calling this backend, it can be used user interface UI, it can be another backend program. Whoever is calling this particular backend program will pass text review, okay? And it will be this class. And this is Pydantic. We have seen this before. Let me define another class, which is analysis. So, analysis is something that Gemini will return. It will return whether the review is positive, negative, neutral, what is the score, theme, and so on. And look at this AI, you know, it is it doesn't have patience. It just wants to write the code for me. Okay. So, this is how it should look like, I think. Uh Is this correct? Yes, this is correct. Let me put one more indentation here. And here you can do 3.5 as well. But anyways, this code is something we have seen before. You are saying analyze this customer review. Label must be positive, negative. Score must be this. Theme must be this. And here you are specifying the output type. It It It is"),
#  Document(metadata={}, page_content="type. It It It is JSON, and it should adhere to this schema. So, you are guiding LLM to produce output in this format. What is the format? The object that LLM returns should have label, score, and theme. And this should be the data type, okay? So, this is what you specify here when you say response schema is this analysis class. Okay, so this back-end is ready. I would like to run that. And to run that, you will just say fast API run API.py. Okay, so it is running it at this location 8000. So, let me click on that. Open. Okay, failed to load. Hold on. So, you will generally say 127.0.0.1. That's how you do it. And see, right now uh there is no like default uh endpoint, but if you do docs, you'll be able to see the Swagger docs, which will show you the endpoint. So, the endpoint that I have is analyze function. And it takes the uh review as an input string. I would like to try it out. And to try it out, you will just say try it out. Pretty simple. And here, I'm going to pass the actual"),
#  Document(metadata={}, page_content="to pass the actual review and execute it. So, now it is calling my back-end and the response is negative, score is two, theme is delivery. See? Cold food again. Of course, it's a negative review. This is the third time the delivery was slow. So, the theme is delivery, the score is two. Okay? So, this is how you test your back-end. You can test your back-end using a tool called Postman also. Okay, this will help you make HTTP calls to the back-end. Anyways, we tested it here. It looks good. Let's now write the front-end. So, for front-end, I will create another file called app.py. And here, I will put all that Streamlit code. So, I used Vibecode to write this code. Nowadays, for writing front-end, I'm not writing it by hand. It's pretty easy using Vibecode approach. And here, what we are doing is this. See? Let Let's ignore this database part initially, okay? So, let me just comment it out. So, the API URL is this, right? We saw that here. This is my URL and {slash} analyze, that is my"),
#  Document(metadata={}, page_content="analyze, that is my endpoint, okay? And when we get the reviews, okay, so reviews will be posted in this kind of uh input box. And when somebody clicks on analyze button, see analyze button here. Then what happens is you take all the reviews and you create a list out of it. So, here it's a list where every element is one review. And you run a for loop on it, okay? And for each review, you will call uh the backend. So, request.post text text that review, and when you get the response back, you will append it to results list. Okay? And that results list, you will show it in the uh frontend, okay? So, once again, folks, I have not written this code. This is totally wipe coded. For frontend, wipe coding works like a charm. You don't have to manually type this in, but of course, you need to understand what it is doing. So, here this is a button click. Here this is how you get text from the input. And then here is how you run the for loop. Every iteration, you are calling the backend for"),
#  Document(metadata={}, page_content="the backend for each review, you get a response. A responses are aggregated in results. And then results, you will show it as a table using the code below, okay? Now, let's think about the database part of it. So, database is going to be a separate file, so let me just database .py. And in this file, once again, it's a simple SQLite database, feedback.db. We just had a session on SQLite, so you know how to create a database, okay? Create the feedback table first. When you are, you know, running the program for the first time. So, the feedback table will have ID, review label, score, and theme. So, whatever response you're getting here, see, let me show you. So, let's say you click on analyze, you're getting all this response, and when you say save report or save database, I change the name of the button. When you say save database, it will save this particular response, which is review label, score, theme, and all these aggregate details, okay? It will save it to this feedback table."),
#  Document(metadata={}, page_content="feedback table. So, here you have all of it, and when you say save results, you are running insert SQL. Okay? And when you say load history, so I'll show you the load history feature in a minute, okay? So, here, my back end is already running here. You see, the back end is already running. I will now create another shell here, and here I'm going to start my front end. So, how do you do it? Streamlit run app.py. Okay? Okay, I was getting init_db not imported from database because I did not have this saved. Now, I have it saved, that is init_db, and that's what I am calling. So, let's run this again. I'm going to give you the sample reviews file. So, let me try only three reviews and analyze. Now, when I call analyze, when I click on analyze button, watch again. So, the analyze, what it will do is it will take the reviews from the front end, it will run the for loop, and it will say request.post API URL. What is API URL? Well, this 1270018000 analyze, okay? And it analyzed it. And you"),
#  Document(metadata={}, page_content="it. And you got all these wonderful reviews. Hooray! This is so amazing. You have your label score quality, you have your summary, and so on. I don't have any saved history, but when I say save to database, it is going to call my database. And see, I have this uh three results saved. I can try few more as well. So, I'm going to try three new reviews, and see, I got this. I can again save it to a database. And now in my saved history, I have this six. So, if you're a restaurant owner, you can bulk download your Google reviews. For example, you can format it into this kind of text file where one line is one review. You can give it to this tool, and this tool will give you very nice analytics. This is a real project, folks. Somebody who is a restaurant owner, or not just restaurant owner, any any type of business owner who is processing reviews will find this project useful. So, this is a really useful business project that you have just built. And if you look at this feedback.db, and by"),
#  Document(metadata={}, page_content="feedback.db, and by the way, you have to install the extension to view the SQLite database. You might not be able to view it directly. You have to go to extension, and just say SQLite viewer or something like that, you know, and install this particular uh extension. Then only you will be able to see this kind of view. But anyways, so here, see, you have review label score, everything. Folks, whenever you have uh this kind of project, it is necessary that you have a good readme.md. And nowadays with AI, you can do this easily. I have Cloud Code extension installed here in my VS Code, that's why I'm seeing all these icons. And here I can say that fill content in readme.md. And it will analyze your project and it will add all the details. If something is missing, you can manually edit it. And once readme is created, you should upload this project to GitHub. If you don't know GitHub, you can find some nice tutorials and upload this project to GitHub, add it to your portfolio. It's going"),
#  Document(metadata={}, page_content="It's going to be very valuable in your job search process and to boost your online credibility. So, see it created my readme.md. If you click on this, you will see the preview. Uh so, see this is how the preview looks like. You see on the on the right-hand side. It's a nice MD file. All right, so this was a pretty good project because you covered database, you covered back end using Fast API, you made calls to LLMs, you had a front end in Streamlit, you used Python's virtual environment, you used for loop, Pydantic. We covered all the topics. Move to the topics that we learned throughout this tutorial and build this end-to-end project. As a next step, what I want you to do is write a nice LinkedIn post and uh just describe your learning lessons from this project. You can link your GitHub repository here. LinkedIn is very important to boost your online credibility. You can tag me, you can tag Code Basics. We have a huge following. When we engage on your post, you are going to get some"),
#  Document(metadata={}, page_content="going to get some visibility as well. So, make sure you are writing a LinkedIn post for this project uh with some modifications and tag me and Code Basics. All right, that's it. If you have any questions, please post in the comment box below. If you want to continue your learning journey, uh refer to this agentic AI crash course. Thank you very much for watching.")]

# %%
from langchain_classic.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

embeddingmodel = OpenAIEmbeddings()

vectorstore = FAISS.from_documents(docs,embeddingmodel)

# %%
vectorstore.index_to_docstore_id
# Out:
# {0: '257b49a2-84f2-4d35-a3b4-5066dbfe31d6',
#  1: '525a38d5-7ce0-40ba-b814-62aa8d25914c',
#  2: 'aecf623c-9783-4853-80af-43f872ed97ad',
#  3: 'd20fff66-2545-44ae-bcaf-4758cce275e2',
#  4: '08345fbb-a1a0-4138-8668-78b079495573',
#  5: '02693676-bb62-4e6e-b73f-be254104c699',
#  6: '263f2475-14bf-42f5-b776-b0af9285d395',
#  7: '90bb9df7-5da1-44cd-9d7c-eb4e7b0ea401',
#  8: '7710a20b-4daa-4ac2-8df2-7d62d5369024',
#  9: '488b751f-4e56-4605-bbf8-3516627d1333',
#  10: 'fdeb5d47-57de-45ae-9237-709b4b321abc',
#  11: 'b13c877f-29aa-40ee-a4a5-e1a3a67b7266',
#  12: '475a339b-47d2-4859-b2a5-506c81d81499',
#  13: 'cf8a3baa-ac6b-43e5-8560-a2c1f0511d77',
#  14: 'dcb51f07-c5e8-48ec-90d6-0cb53418c9e0',
#  15: 'ba05c394-29c8-411a-ac90-b56656e45c56',
#  16: '6b9278fe-6f46-45eb-983e-a0d18f563eed',
#  17: '7652279e-1559-4656-ba7c-61e556c50ecb',
#  18: 'b122cb80-b193-4c68-b8ee-879942756811',
#  19: 'fc869145-b028-432e-83d2-70e3cbdd5485',
#  20: 'b610efba-ca20-47b6-ac8c-f4cc862e3ace',
#  21: '56a61cd4-32a7-4240-bdd9-160a085e5c4d',
#  22: '34b23191-0b0b-4ac6-8f5c-8df78f81e52e',
#  23: '4be5b6bd-be65-4f7f-9dee-781eab2a0abb',
#  24: 'f657c055-a487-4144-93f2-5adec595fbfe',
#  25: 'ff249a4f-e5df-4031-9ad7-8284d46e74a6',
#  26: 'e7b20c60-d75c-47bf-b324-a0ed56883d16',
#  27: '6caf3c70-d6a9-4901-bbe5-74a11865ba36',
#  28: '2d3abac8-f910-4a31-b9d2-52f933ab7f9c',
#  29: '922cfbca-4ca0-4d64-b92f-d9b6bc41ec47',
#  30: '8705e204-2869-443f-b1c0-96202d9b8e6b',
#  31: '0d033c64-b9df-4c09-b102-8443c584d80d',
#  32: '5b3e9fdd-0731-4868-8267-08b045e7f880',
#  33: '991ddfdb-362c-42ae-bf31-fcd8b55dac0c',
#  34: '653a9955-8e12-497f-b275-abfd132d26de',
#  35: '66544a58-fd5b-4d95-a5a7-f4c6446db4f8',
#  36: '796284c3-2341-45bd-b69b-7343ac81a3ec',
#  37: 'ba8cb961-35a4-4a14-8cd1-09a452f4eaf0',
#  38: '30396bb6-f785-42f0-902a-034be9035621',
#  39: '8ec8ed1f-94fb-4940-80eb-64aeff5b0402',
#  40: '1e0bfd1d-4b28-4e70-9577-d9f42f1125e9',
#  41: '6b1f0102-29ce-48dc-a3a1-fb028efd2d1c',
#  42: '4c3e7442-4b5e-4a97-99db-775ce3bf5463',
#  43: 'd17eb08c-8ec6-45d3-b574-39fc35016f2f',
#  44: 'c2f53a08-c9b1-496f-beb1-ead40ebcc1fd',
#  45: '66a02236-b7f6-46da-a502-713ee86cdda3',
#  46: '0117f119-d99d-467e-9559-021f8c3d29ab',
#  47: '57bfe653-5788-425e-9ec2-899bc9ec71d9',
#  48: '562cb18f-3820-4713-ba9a-7da006289bad',
#  49: '9b429614-c57e-44c5-8cfa-ab560bfca268',
#  50: '7728d5bd-c713-4269-84dd-5f02e3b66867',
#  51: 'd98abd0d-4ea9-4d7d-9ca8-5f376fdd2eed',
#  52: '06f0a9f7-0dbd-412c-bd2f-c2020ec417b2',
#  53: '4a53b4b4-4c7a-4480-ad2a-1a0d79ba9abe',
#  54: 'c7309ce6-18ab-4e71-9803-e213a9d4dd61',
#  55: 'b22c29f3-8d6f-4d09-b928-80de59c8982a',
#  56: 'd75dbd6c-694c-4b6c-b534-de63d1fa6bf4',
#  57: '04131654-a3d5-4703-8aa3-ae1e57d63a43',
#  58: '45bbed89-e5f0-4663-ad00-6a854f387e71',
#  59: 'c5a724a1-ec42-43cd-9b18-91fe3c17ac09',
#  60: '725f4047-f654-4459-b5dd-af2385ff9091',
#  61: '282f2148-5731-4516-a8f8-9e77f99e635a',
#  62: '3dc5e09b-2f71-4b1f-9bd8-bb6a12085352',
#  63: 'f45ebb29-56f0-48ee-996b-878a51c25306',
#  64: 'f9c7e624-ea5e-434f-9782-5be690116e53',
#  65: '019883f3-4121-4ee4-a324-927bafe14a39',
#  66: '5bcbc57b-d639-4dd7-8ac6-1d0425ddcc05',
#  67: '061b191d-91e6-43c3-beda-29333da5d9ba',
#  68: '5067ba8d-0b66-444a-b13a-07afc805cf7b',
#  69: '1e591777-ab82-44d1-af6c-4f92b2fa4810',
#  70: '04504437-0b7a-4913-bd93-2bb9395db139',
#  71: '9f40a706-0b98-44ff-9cb9-60bb164f2a4c',
#  72: 'f26e69c0-ce37-4a2f-9800-63c30566db71',
#  73: 'eac342a5-c28f-4fde-9ff5-8231591c28e2',
#  74: 'bd0ee82b-d870-430f-a764-d0fdad3486c0',
#  75: '99b61d3e-24d5-447f-9016-8b1b4d572d23',
#  76: '2a1650f4-7bbe-4fd9-a190-4b226be6018c',
#  77: '3f5858d9-0325-4c01-bc02-db9ec8f1ccb5',
#  78: '0cf7ff60-d697-4d98-987f-8423f5aa5a66',
#  79: 'f35ce5e6-ff3f-4192-bd73-117c2f0e38db',
#  80: 'a59490d8-a6cd-4ff3-a276-4135951d3e16',
#  81: '09c40060-1bea-46ab-962e-df4cddab9cfe',
#  82: 'bfd5f30f-2c0a-413b-9be8-fbfeaa83b1e7',
#  83: '90e7786f-0a57-4c16-822e-3036df03bb56',
#  84: '92ab9c11-21a0-4efe-9b4c-d7221ff102be',
#  85: '51ce61df-7c63-4d41-b0d4-b9e4443fa55b',
#  86: '493730ed-8520-4da4-bee1-6b75eabb11ca',
#  87: '8faa510b-0116-4313-9863-08aceda51958',
#  88: '353145c9-e3e6-4b84-a14f-a4f0287c0fde',
#  89: '558ac8fd-71ab-407b-8deb-85217d797448',
#  90: '44053b3b-be67-4298-bedc-830306dc8243',
#  91: '5437215c-c848-4665-8df4-58cc08086082',
#  92: 'e76f00a0-a8ac-4bcc-8e97-c2449b08bb0c',
#  93: 'de3e3f73-4040-4865-a2d1-6a7412089a0e',
#  94: 'ca27df4e-cc55-406a-bde3-3a46d178d094',
#  95: 'fbc1db15-45c6-4751-a207-960511741ef0',
#  96: '89057857-9306-4731-807e-97b9ad7bd82b',
#  97: '1a425845-45d5-42a0-b7b7-920958de738c',
#  98: 'fe09daef-1091-462b-975c-cf756a18bd33'}

# %%
query = 'What tool is used as frontent?'

# %%
retriever = vectorstore.as_retriever(search_kwargs = {"k":3})

# %%
retrieved_doc = retriever.invoke(query)

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

llm = ChatOpenAI()

template = PromptTemplate(
    template= """
    Act as helpful assistant and provide the information on below query based on provided context below. If information is not sufficient then say I dont know.
    {context},
    question : {query}
    """,
    input_variables=['context','query']
)

# %%
context = "\n\n".join(doc.page_content for doc in retrieved_doc)
context
# Out:
# "front end, we are using Streamlit because it helps you develop things quickly. When it comes to production, people do not use Streamlit usually. They use something called React or any other JavaScript framework. You can build a front-end in React using Vibe coding very easily. So, if you want to try it out, you can try it out that as well. Uh but, as far as this project is concerned, we will stick to Streamlit. To get started, I have created this folder called project feedback analyzer. And to keep things clean in the left panel, I will open that folder so that I I don't want to see other files. So, here I will open this particular folder so that I have a clean file view. See? I don't have anything other than the empty folder. Now, let me add a file for sample reviews, okay? So, sample reviews.txt. And I have some reviews. Every line is one review, okay? So, this is what we have. Now, we are going to use something called a virtual environment for this project. Why is virtual\n\nto pass the actual review and execute it. So, now it is calling my back-end and the response is negative, score is two, theme is delivery. See? Cold food again. Of course, it's a negative review. This is the third time the delivery was slow. So, the theme is delivery, the score is two. Okay? So, this is how you test your back-end. You can test your back-end using a tool called Postman also. Okay, this will help you make HTTP calls to the back-end. Anyways, we tested it here. It looks good. Let's now write the front-end. So, for front-end, I will create another file called app.py. And here, I will put all that Streamlit code. So, I used Vibecode to write this code. Nowadays, for writing front-end, I'm not writing it by hand. It's pretty easy using Vibecode approach. And here, what we are doing is this. See? Let Let's ignore this database part initially, okay? So, let me just comment it out. So, the API URL is this, right? We saw that here. This is my URL and {slash} analyze, that is my\n\nwindow. And look at this, folks. Your your application is ready, see? In just one prompt, we created a UI app. So, here you will specify all the ingredients. Tell me what kind of food you want to eat. I will say aloo peas with flour. I hope you're getting where I'm going with this. The cuisine is Indian. The diet is vegetarian. And generate a recipe. And it give the error because 2. 0 flash is not available. So, we need to uh use whatever model we have in this, see? I I want to use this flash model somehow. See, Y coding is not perfect. See, this shows that Y coding is not perfect. You need to have understanding of your code is doing. Otherwise, if you treat it like a box, then you know, you'll have problem because this AI can always make mistakes. See, it generated a recipe, aloo matar paratha. I hope it created a recipe for samosa. But this is so powerful. You have a front end working where you can give the input and you can generate a recipe, okay? So, Streamlit, folks, is a way to"

# %%
# Preview the rendered prompt for debugging (don’t overwrite `template`)
prompt_preview = template.invoke({'query': query, 'context': context})
prompt_preview
# Out:
# StringPromptValue(text="\n    Act as helpful assistant and provide the information on below query based on provided context below. If information is not sufficient then say I dont know.\n    front end, we are using Streamlit because it helps you develop things quickly. When it comes to production, people do not use Streamlit usually. They use something called React or any other JavaScript framework. You can build a front-end in React using Vibe coding very easily. So, if you want to try it out, you can try it out that as well. Uh but, as far as this project is concerned, we will stick to Streamlit. To get started, I have created this folder called project feedback analyzer. And to keep things clean in the left panel, I will open that folder so that I I don't want to see other files. So, here I will open this particular folder so that I have a clean file view. See? I don't have anything other than the empty folder. Now, let me add a file for sample reviews, okay? So, sample reviews.txt. And I have some reviews. Every line is one review, okay? So, this is what we have. Now, we are going to use something called a virtual environment for this project. Why is virtual\n\nto pass the actual review and execute it. So, now it is calling my back-end and the response is negative, score is two, theme is delivery. See? Cold food again. Of course, it's a negative review. This is the third time the delivery was slow. So, the theme is delivery, the score is two. Okay? So, this is how you test your back-end. You can test your back-end using a tool called Postman also. Okay, this will help you make HTTP calls to the back-end. Anyways, we tested it here. It looks good. Let's now write the front-end. So, for front-end, I will create another file called app.py. And here, I will put all that Streamlit code. So, I used Vibecode to write this code. Nowadays, for writing front-end, I'm not writing it by hand. It's pretty easy using Vibecode approach. And here, what we are doing is this. See? Let Let's ignore this database part initially, okay? So, let me just comment it out. So, the API URL is this, right? We saw that here. This is my URL and {slash} analyze, that is my\n\nwindow. And look at this, folks. Your your application is ready, see? In just one prompt, we created a UI app. So, here you will specify all the ingredients. Tell me what kind of food you want to eat. I will say aloo peas with flour. I hope you're getting where I'm going with this. The cuisine is Indian. The diet is vegetarian. And generate a recipe. And it give the error because 2. 0 flash is not available. So, we need to uh use whatever model we have in this, see? I I want to use this flash model somehow. See, Y coding is not perfect. See, this shows that Y coding is not perfect. You need to have understanding of your code is doing. Otherwise, if you treat it like a box, then you know, you'll have problem because this AI can always make mistakes. See, it generated a recipe, aloo matar paratha. I hope it created a recipe for samosa. But this is so powerful. You have a front end working where you can give the input and you can generate a recipe, okay? So, Streamlit, folks, is a way to,\n    question : What tool is used as frontent?\n    ")

# %%
result = llm.invoke(prompt_preview)
result.content
# Out:
# 'The tool used for the front-end development in this project is Streamlit.'

# %% [markdown]
# #### LCEL

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda

query = 'What modules get covered in this video'

def generate_context(retrieved_documents):
    return "/n".join(doc.page_content for doc in retrieved_documents)
    

parallel_chain = RunnableParallel({
    'context' : retriever | RunnableLambda(generate_context),
    'query' : RunnablePassthrough()
})

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

chain = parallel_chain | template | llm | parser

chain.invoke(query)
# Out:
# 'The modules covered in this video include Gen AI module from Google, Fast API for the backend, Pydantic, and the datetime module in Python for computing age.'
