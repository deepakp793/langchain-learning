# %%
from langchain_chroma import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_core.documents import Document

# %%
documents = [
    Document(page_content="LangChain helps developers build LLM applications easily."),
    Document(page_content="Chroma is a vector database optimized for LLM-based search."),
    Document(page_content="Embeddings convert text into high-dimensional vectors."),
    Document(page_content="OpenAI provides powerful embedding models."),
]

# %%
embedding_model = OpenAIEmbeddings()

vector_store = Chroma.from_documents(
    embedding= embedding_model,
    documents= documents,
    collection_name='my_collecttion',
    persist_directory='chroma_db'
)

# %%
retriever = vector_store.as_retriever(search_kwargs={"k":2})

# %%
query = 'What is chromadb'

retriever.invoke(query)
# Out:
# [Document(id='6f11e2e0-9df6-45ce-9371-92156c7aec25', metadata={}, page_content='Chroma is a vector database optimized for LLM-based search.'),
#  Document(id='216573df-2494-49b8-a140-cdd2cc4a90c6', metadata={}, page_content='LangChain helps developers build LLM applications easily.')]
