# %%
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_openai import ChatOpenAI
from langchain.agents import create_agent
from langchain_classic.agents import AgentExecutor
from langchain_core.messages import HumanMessage

# %%
llm = ChatOpenAI()
llm.invoke('Hi')
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-E2WuFlFgdievLcESfqmdURbOw3u85', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f6ee3-d9ec-7792-b567-f9486d9de66b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
search_tool = DuckDuckGoSearchRun()
tools = [search_tool]

# %%
agent = create_agent(model ="openai:gpt-4o", tools=tools)

# %%
query = HumanMessage("What is todays weather of cultural capital of maharashtra")

agent.invoke({"messages":[query]})
# Out:
# {'messages': [HumanMessage(content='What is todays weather of cultural capital of maharashtra', additional_kwargs={}, response_metadata={}, id='f4f6801e-f1c0-47d2-83eb-aebf9225ecce'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 84, 'total_tokens': 104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb185bfc03', 'id': 'chatcmpl-E2X6Z38IvOWewm3PiddslXkfg98el', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f6eef-88c3-7082-84e0-e368b7e4a082-0', tool_calls=[{'name': 'duckduckgo_search', 'args': {'query': 'Pune weather today'}, 'id': 'call_RyPTSg5cRF3M68o8Iqau02Ku', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 84, 'output_tokens': 20, 'total_tokens': 104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="Get today's real-time weather updates in Pune with hourly temperatures and a weekly forecast. Find out about Pune's temperature trends, rain chances, air quality (AQI), and humidity, all updated ... Get the latest hourly weather updates for Pune today. Detailed forecast including temperature, wind, rain, snow, and UV index. Stay informed about today's weather conditions in Pune. Weather in Pune : Check here live Pune weather (पुणे मौसम) and temperature (तापमान) details alongside upcoming week rain and weather forecast at Aajtak online. Get the latest Pune weather updates! Check today’s forecast, temperature, humidity, hourly updates rain alerts. Stay prepared with real-time Pune weather reports! Pune, Maharashtra, India Weather Forecast, with current conditions, wind, air quality, and what to expect for the next 3 days.", name='duckduckgo_search', id='98a43197-d650-4650-a47f-a924df51d7a4', tool_call_id='call_RyPTSg5cRF3M68o8Iqau02Ku'),
#   AIMessage(content="For today's weather in Pune, the cultural capital of Maharashtra, you can find real-time updates including temperature, rain chances, air quality index (AQI), and humidity. Stay informed about the current weather conditions, hourly forecasts, and any alerts. For precise details, you might want to check a reliable weather service or app.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 281, 'total_tokens': 347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_eb185bfc03', 'id': 'chatcmpl-E2X6fqGJ4esJBKx9uvrFzIMp8vfPC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f6eef-9c09-76b1-8880-3d1b5b3d606a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 281, 'output_tokens': 66, 'total_tokens': 347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
